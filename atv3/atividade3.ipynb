# %% [markdown]
# Atividade Prática Supervisionada
# Atividade 03: Introdução à
#
# Grupo:
# <ul>
# <li>João Pedro Mendonça Oliveira
# <li>Antonio Gabriel Batista Souza
# <li>Diego Alessandro Batista Santos
# <ul>

# %%
import pandas as pd

# %%
# Leitura dos dados
df= pd.read_csv('Cópia de dados_atividade_3_alunos - dados_atividade_3.csv')
df
# Out:
#                          Abastecimento de água - Brasil   Unnamed: 1  \
# 0                         Moradores por Município e Ano          NaN
# 1                                          Período:1991         2000
# 2                        Município;"1991";"2000";"2010"          NaN
# 3        110001 Alta Floresta D'Oeste;31870;25951;24054          NaN
# 4          110037 Alto Alegre dos Parecis;-;12425;12758          NaN
# ...                                                 ...          ...
# 5566                   522230 Vila Propício;-;4191;4784          NaN
# 5567            530010 Brasília;1586552;2035224;2543040          NaN
# 5568                Total;145657806;168370893;189461396          NaN
# 5569          Fonte: IBGE - Censos Demográficos de 1991  2000 e 2010
# 5570  Consulte o site da Secretaria Estadual de Saúd...          NaN
#
#       Unnamed: 2
# 0            NaN
# 1         2010.0
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 5566         NaN
# 5567         NaN
# 5568         NaN
# 5569         NaN
# 5570         NaN
#
# [5571 rows x 3 columns]

# %%
# Tratamento dos dados

# Separa a coluna que contém os dados (coluna 1) em 4 colunas e remove as linhas inúteis
df = dict(df['Abastecimento de água - Brasil'].str.split(';')[2:-2])

# Faz a transposição 
df = pd.DataFrame(df).T

# Atualiza o header do df para a primeira linha e remove aspas das strings
df.columns = df.iloc[0].str.replace(pat="\"",repl="")

# Reseta o índice agora com um novo df
df.reset_index(drop=True, inplace=True)

# Remove a primeira linha agora que ela é o header
df = df.drop(0)

# Remove nome da coluna de índices
df.columns.name = None
df
# Out:
#                            Município       1991       2000       2010
# 1       110001 Alta Floresta D'Oeste      31870      25951      24054
# 2     110037 Alto Alegre dos Parecis          -      12425      12758
# 3                110040 Alto Paraíso          -      12174      17098
# 4            110034 Alvorada D'Oeste      20956      19745      16677
# 5                   110002 Ariquemes      83208      71874      89635
# ...                              ...        ...        ...        ...
# 5562           522205 Vicentinópolis       5132       5970       7279
# 5563                 522220 Vila Boa          -       3262       4700
# 5564            522230 Vila Propício          -       4191       4784
# 5565                 530010 Brasília    1586552    2035224    2543040
# 5566                           Total  145657806  168370893  189461396
#
# [5566 rows x 4 columns]

# %% [markdown]
# PRÁTICA 1: Utilizando a linguagem R ou Python obtenha para cada ano uma amostra aleatória simples de
# 70 municípios.

# %%
import numpy as np

# %%
df.columns
print(df['Município'].iloc[0])
# Out:
# 110001 Alta Floresta D'Oeste

# %%
# Extrai amostras aleatórias simples de 70 municípios para cada ano
amostra = { 1991 : [], 2000 : [], 2010 : [] }
for ano in amostra:
    m = np.random.choice(df.index, 70)
    for idx in m:
        amostra[ano].append((df['Município'].iloc[idx],df[str(ano)].iloc[idx]))

# Imprime as amostras por ano
for ano in amostra:
    print(f"Amostras do ano {ano}:")
    for idx, a in enumerate(amostra[ano]):
        print(idx, ":",a)
# Out:
# Amostras do ano 1991:
# 0 : ('313545 Jenipapo de Minas', '-')
# 1 : ('261440 Solidão', '5758')
# 2 : ('355500 Tupã', '60853')
# 3 : ('313400 Itinga', '22541')
# 4 : ('330320 Nilópolis', '157901')
# 5 : ('160020 Calçoene', '5094')
# 6 : ('351518 Espírito Santo do Pinhal', '36546')
# 7 : ('260590 Gameleira', '19513')
# 8 : ('220400 Francinópolis', '5309')
# 9 : ('270895 Senador Rui Palmeira', '9404')
# 10 : ('410855 Godoy Moreira', '5291')
# 11 : ('353910 Pirapora do Bom Jesus', '7921')
# 12 : ('520357 Bonópolis', '-')
# 13 : ('315600 Rio Vermelho', '15826')
# 14 : ('270280 Flexeiras', '12017')
# 15 : ('314180 Minas Novas', '33522')
# 16 : ('350730 Boracéia', '3449')
# 17 : ('431406 Passa Sete', '-')
# 18 : ('500290 Cassilândia', '17779')
# 19 : ('130070 Boca do Acre', '24442')
# 20 : ('353040 Mirassolândia', '3015')
# 21 : ('352470 Jaguariúna', '24506')
# 22 : ('314160 Mercês', '10036')
# 23 : ('250157 Barra de Santana', '-')
# 24 : ('250435 Caturité', '-')
# 25 : ('290700 Cardeal da Silva', '6377')
# 26 : ('510480 Jaciara', '21740')
# 27 : ('352490 Jambeiro', '3265')
# 28 : ('171180 Juarina', '-')
# 29 : ('171180 Juarina', '-')
# 30 : ('421055 Marema', '6560')
# 31 : ('261340 São José da Coroa Grande', '11452')
# 32 : ('150563 Piçarra', '-')
# 33 : ('210467 Governador Nunes Freire', '-')
# 34 : ('351400 Dobrada', '6688')
# 35 : ('316295 São José da Lapa', '-')
# 36 : ('330575 Tanguá', '-')
# 37 : ('432145 Teutônia', '17528')
# 38 : ('420230 Biguaçu', '33872')
# 39 : ('510350 Diamantino', '15702')
# 40 : ('352600 Junqueirópolis', '17649')
# 41 : ('310690 Bicas', '11189')
# 42 : ('351830 Guararema', '17730')
# 43 : ('317047 Uruana de Minas', '-')
# 44 : ('313840 Leopoldina', '45993')
# 45 : ('420125 Apiúna', '7666')
# 46 : ('354325 Ribeirão Grande', '-')
# 47 : ('522230 Vila Propício', '-')
# 48 : ('150442 Marituba', '-')
# 49 : ('230015 Acarape', '10185')
# 50 : ('171820 Porto Nacional', '42836')
# 51 : ('430066 André da Rocha', '1042')
# 52 : ('355200 Silveiras', '4855')
# 53 : ('293100 Tanhaçu', '18259')
# 54 : ('420010 Abelardo Luz', '17688')
# 55 : ('316510 São Tomás de Aquino', '6865')
# 56 : ('421660 São José', '138194')
# 57 : ('355255 Suzanápolis', '-')
# 58 : ('150010 Abaetetuba', '99803')
# 59 : ('311420 Carmo do Cajuru', '14383')
# 60 : ('520680 Damolândia', '2577')
# 61 : ('315820 Santa Maria do Suaçuí', '18218')
# 62 : ('310930 Buritis', '18324')
# 63 : ('521486 Nova Glória', '8490')
# 64 : ('290170 Antônio Cardoso', '11289')
# 65 : ('430512 Cerrito', '-')
# 66 : ('351420 Dolcinópolis', '2091')
# 67 : ('210610 Loreto', '9433')
# 68 : ('330390 Petrópolis', '252600')
# 69 : ('231130 Quixadá', '72050')
# Amostras do ano 2000:
# 0 : ('220450 Guadalupe', '10243')
# 1 : ('312250 Dom Cavati', '5445')
# 2 : ('250350 Cacimba de Dentro', '16767')
# 3 : ('510325 Colniza', '-')
# 4 : ('355650 Várzea Paulista', '92532')
# 5 : ('220553 Jurema', '4010')
# 6 : ('313640 Joaquim Felício', '3579')
# 7 : ('411721 Nova Santa Bárbara', '3611')
# 8 : ('230540 Icó', '62228')
# 9 : ('354510 Salmourão', '4390')
# 10 : ('411110 Itambé', '5952')
# 11 : ('320290 Itarana', '11357')
# 12 : ('290515 Caetanos', '13058')
# 13 : ('430495 Caseiros', '2826')
# 14 : ('355130 Sebastianópolis do Sul', '2546')
# 15 : ('130185 Iranduba', '31141')
# 16 : ('351510 Embu-Guaçu', '55777')
# 17 : ('240420 Goianinha', '17620')
# 18 : ('293070 Simões Filho', '93391')
# 19 : ('352780 Lupércio', '4218')
# 20 : ('150150 Benevides', '34971')
# 21 : ('292090 Mascote', '15886')
# 22 : ('210462 Governador Luiz Rocha', '6456')
# 23 : ('350995 Canas', '3612')
# 24 : ('251445 São José dos Ramos', '4885')
# 25 : ('421140 Nova Erechim', '3471')
# 26 : ('353050 Mococa', '64792')
# 27 : ('220200 Buriti dos Lopes', '18494')
# 28 : ('330420 Resende', '103906')
# 29 : ('330510 São João de Meriti', '448531')
# 30 : ('500770 Sete Quedas', '10729')
# 31 : ('500020 Água Clara', '10730')
# 32 : ('352590 Jundiaí', '320687')
# 33 : ('220975 São Gonçalo do Gurguéia', '2310')
# 34 : ('330575 Tanguá', '25920')
# 35 : ('280190 Cumbe', '3636')
# 36 : ('230840 Missão Velha', '32185')
# 37 : ('312050 Cristina', '10277')
# 38 : ('351000 Cândido Mota', '29075')
# 39 : ('353860 Piracaia', '22844')
# 40 : ('150613 Redenção', '62705')
# 41 : ('520505 Castelândia', '3743')
# 42 : ('210043 Alto Alegre do Maranhão', '19563')
# 43 : ('250730 Jacaraú', '14007')
# 44 : ('280190 Cumbe', '3636')
# 45 : ('410930 Guaraniaçu', '16874')
# 46 : ('311450 Carmópolis de Minas', '14233')
# 47 : ('313695 Juvenília', '7052')
# 48 : ('431190 Marcelino Ramos', '5991')
# 49 : ('220345 Dom Inocêncio', '8906')
# 50 : ('292530 Porto Seguro', '92485')
# 51 : ('311590 Chácara', '2319')
# 52 : ('521090 Itapaci', '13754')
# 53 : ('261180 Ribeirão', '41078')
# 54 : ('310780 Bom Jesus do Galho', '16093')
# 55 : ('352360 Itirapina', '11281')
# 56 : ('350450 Avaré', '74212')
# 57 : ('291750 Jacobina', '75664')
# 58 : ('510780 Santo Antônio do Leverger', '14475')
# 59 : ('240220 Canguaretama', '26696')
# 60 : ('520840 Goianápolis', '10573')
# 61 : ('220887 Ribeira do Piauí', '3870')
# 62 : ('412860 Verê', '8637')
# 63 : ('260780 Itaquitinga', '14925')
# 64 : ('290670 Cândido Sales', '28180')
# 65 : ('520660 Cumari', '3058')
# 66 : ('351160 Cesário Lange', '11964')
# 67 : ('521305 Mimoso de Goiás', '2770')
# 68 : ('270280 Flexeiras', '11437')
# 69 : ('240680 Lajes Pintadas', '4527')
# Amostras do ano 2010:
# 0 : ('240470 Ipanguaçu', '13800')
# 1 : ('240640 Lagoa de Velhos', '2639')
# 2 : ('311890 Cordisburgo', '8624')
# 3 : ('520090 Amorinópolis', '3527')
# 4 : ('150815 Uruará', '44275')
# 5 : ('500480 Japorã', '7673')
# 6 : ('292990 Seabra', '41642')
# 7 : ('500280 Caracol', '5375')
# 8 : ('261280 Santa Terezinha', '10973')
# 9 : ('351310 Cravinhos', '31615')
# 10 : ('280030 Aracaju', '565749')
# 11 : ('310490 Baependi', '18111')
# 12 : ('510250 Cáceres', '87457')
# 13 : ('211050 São Bento', '40616')
# 14 : ('351950 Ibirarema', '6703')
# 15 : ('220890 Ribeiro Gonçalves', '6795')
# 16 : ('210790 Passagem Franca', '17483')
# 17 : ('310220 Alvarenga', '4433')
# 18 : ('315610 Ritápolis', '4924')
# 19 : ('310620 Belo Horizonte', '2357212')
# 20 : ('352140 Iracemápolis', '19954')
# 21 : ('521900 Sanclerlândia', '7503')
# 22 : ('314750 Passabém', '1757')
# 23 : ('430130 Arroio Grande', '18395')
# 24 : ('320035 Alto Rio Novo', '7311')
# 25 : ('431125 Lagoão', '6156')
# 26 : ('355240 Sumaré', '240849')
# 27 : ('316920 Tombos', '9480')
# 28 : ('521385 Morro Agudo de Goiás', '2348')
# 29 : ('352330 Itariri', '15403')
# 30 : ('170215 Araguanã', '5017')
# 31 : ('315120 Pirapora', '52901')
# 32 : ('260140 Barreiros', '39645')
# 33 : ('330150 Cordeiro', '20410')
# 34 : ('432335 Vila Lângaro', '2143')
# 35 : ('316390 São Pedro da União', '5009')
# 36 : ('411095 Itaipulândia', '8939')
# 37 : ('420240 Blumenau', '306415')
# 38 : ('250450 Condado', '6523')
# 39 : ('320190 Domingos Martins', '31697')
# 40 : ("315053 Pingo-d'Água", '4414')
# 41 : ('432280 Veranópolis', '22705')
# 42 : ('431750 Santo Ângelo', '75625')
# 43 : ('353880 Piraju', '28344')
# 44 : ('431670 Santa Bárbara do Sul', '8809')
# 45 : ('150430 Maracanã', '28220')
# 46 : ('432190 Três Passos', '23545')
# 47 : ('520993 Inaciolândia', '5693')
# 48 : ('150345 Ipixuna do Pará', '51163')
# 49 : ('251420 São José da Lagoa Tapada', '7554')
# 50 : ('520790 Flores de Goiás', '10667')
# 51 : ('280260 Gracho Cardoso', '5602')
# 52 : ('260660 Ibimirim', '26840')
# 53 : ('330520 São Pedro da Aldeia', '87653')
# 54 : ('421635 São João do Itaperiú', '3415')
# 55 : ('330200 Itaguaí', '108873')
# 56 : ('351430 Dourado', '8569')
# 57 : ('430430 Cândido Godói', '6506')
# 58 : ('351130 Cedral', '7939')
# 59 : ('290420 Botuporã', '11122')
# 60 : ('315770 Santa Juliana', '11293')
# 61 : ('293170 Terra Nova', '12786')
# 62 : ('410645 Coronel Domingos Soares', '7207')
# 63 : ('430215 Boa Vista das Missões', '2111')
# 64 : ('431402 Paraíso do Sul', '7320')
# 65 : ('520740 Edéia', '11181')
# 66 : ('311560 Cedro do Abaeté', '1209')
# 67 : ('430223 Boa Vista do Incra', '2400')
# 68 : ("354740 Santa Rita d'Oeste", '2536')
# 69 : ('420195 Balneário Arroio do Silva', '9543')
